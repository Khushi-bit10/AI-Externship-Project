# %%
import pandas as pd
import numpy as np
A = {'c1': [np.random.randint(10),np.random.randint(10),np.random.randint(10),np.random.randint(10)] , 'c2': [np.random.randint(10),np.random.randint(10),np.random.randint(10),np.random.randint(10)] , 'c3': [np.random.randint(10),np.random.randint(10),np.random.randint(10),np.random.randint(10)] , 'c4': [np.random.randint(10),np.random.randint(10),np.random.randint(10),np.random.randint(10)]}
df = pd.DataFrame(A)
df
# Out:
#    c1  c2  c3  c4
# 0   2   6   7   1
# 1   4   9   9   5
# 2   9   1   2   1
# 3   2   6   7   0

# %%
df.rename(columns = {'c1':'Random Value 1'}, inplace = True)
df.rename(columns = {'c2':'Random Value 2'}, inplace = True)
df.rename(columns = {'c3':'Random Value 3'}, inplace = True)
df.rename(columns = {'c4':'Random Value 4'}, inplace = True)
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0               2               6               7               1
# 1               4               9               9               5
# 2               9               1               2               1
# 3               2               6               7               0

# %%
stats = df['Random Value 1'].describe()
stats
# Out:
# count    4.000000
# mean     4.250000
# std      3.304038
# min      2.000000
# 25%      2.000000
# 50%      3.000000
# 75%      5.250000
# max      9.000000
# Name: Random Value 1, dtype: float64

# %%
boolans = df['Random Value 1'].isnull()
boolans
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: Random Value 1, dtype: bool

# %%
result1 = df.iloc[:,1:3]
result1
# Out:
#    Random Value 2  Random Value 3
# 0               6               7
# 1               9               9
# 2               1               2
# 3               6               7

# %%
result2 = df.loc[:,'Random Value 2':'Random Value 3']
result2
# Out:
#    Random Value 2  Random Value 3
# 0               6               7
# 1               9               9
# 2               1               2
# 3               6               7
